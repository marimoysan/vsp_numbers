# %%
import streamlit as st
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Define el scope y crea las credenciales (usando secrets si estás en Streamlit Cloud)
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/spreadsheets",
         "https://www.googleapis.com/auth/drive", "https://www.googleapis.com/auth/drive.file"]

# %%
# Arreglar clave privada si viene como string con saltos reales
key_info = dict(st.secrets["gcp_service_account"])
key_info["private_key"] = key_info["private_key"].replace("\\n", "\n") if "\\n" in key_info["private_key"] else key_info["private_key"]

# %%
# Desde secrets (recomendado para Streamlit Cloud)
creds = Credentials.from_service_account_info(st.secrets["gcp_service_account"], scopes=scope)

# %%
# 2. Autenticación y conexión al Google Sheet
client = gspread.authorize(creds)

# %%
# 3. Abre el Google Sheet por su nombre (también puedes usar su URL o ID)
spreadsheet = client.open("Planning_Tracker_VSP")

# %%
# 4. Selecciona la hoja "Transferencias"
worksheet = spreadsheet.worksheet("Transferencias")

# %%
# 5. Convierte el contenido en DataFrame
data = worksheet.get_all_records()  # devuelve una lista de diccionarios
df_transferencias = pd.DataFrame(data)

# %%
df_transferencias
# Out:
#                                              Evento             Grupo  \
# 0           TIQETS--Espectáculo flamenco-18/10/2023        Transporte
# 1     CITITRAVEL-Astellas-iPad Challenge-24/10/2023         Actividad
# 2                                                             Oficina
# 3               Faunia-UCI-iPad Challenge-3/10/2023  comida y parking
# 4                 CIL-María José-Mariachi-8/10/2023       Subcontrata
# ...                                             ...               ...
# 2345
# 2346
# 2347
# 2348
# 2349
#
#      F. Operativa                        Transferencia Subgrupo  \
# 0       4/09/2023        Añadido manualmente por Marco     Pago
# 1      14/09/2023        Añadido manualmente por Marco    Cobro
# 2       2/10/2023     TRANSFERENCIA A JOSEBA G. ANGULO     Pago
# 3       3/10/2023        Añadido manualmente por Marco     Pago
# 4       3/10/2023  TRANSFERENCIA A JUAN LUIS DOMÍNGUEZ     Pago
# ...           ...                                  ...      ...
# 2345
# 2346
# 2347
# 2348
# 2349
#
#      Valor ( + ) / ( - ) Fecha Valor   MES   AÑO Semana C/P  ... Año I/G  \
# 0               -130,68€   4/09/2023  sept  2023         36  ...
# 1                647,97€  14/09/2023  sept  2023         37  ...
# 2               -351,24€  28/12/2023   oct  2023         40  ...
# 3                -36,30€   3/10/2023   oct  2023         40  ...
# 4               -165,00€  31/10/2023   oct  2023         40  ...
# ...                  ...         ...   ...   ...        ...  ...     ...
# 2345                                   dic  1899             ...
# 2346                                   dic  1899             ...
# 2347                                   dic  1899             ...
# 2348                                   dic  1899             ...
# 2349                                   dic  1899             ...
#
#      Fecha evento Cliente Tipo Actividad comprobar duplicados Grupo_1_FDC  \
# 0                                                                    Pago
# 1                                                                   Cobro
# 2                                                                    Pago
# 3                                                                    Pago
# 4                                                                    Pago
# ...           ...     ...            ...                  ...         ...
# 2345                                                                 Pago
# 2346                                                                 Pago
# 2347                                                                 Pago
# 2348                                                                 Pago
# 2349                                                                 Pago
#
#                Grupo_2_FDC            Grupo_3_FDC  \
# 0      Pago de Actividades             Transporte
# 1     Cobro de Actividades              Actividad
# 2                    Otros                Oficina
# 3      Pago de Actividades  Comidas y Alojamiento
# 4      Pago de Actividades            Subcontrata
# ...                    ...                    ...
# 2345
# 2346
# 2347
# 2348
# 2349
#
#              Grupos_Flujo_de_Caja Fecha Grafico
# 0     Pago Variable - Actividades        9/2023
# 1     Pago Variable - Actividades
# 2                       Pago Fijo
# 3     Pago Variable - Actividades
# 4     Pago Variable - Actividades
# ...                           ...           ...
# 2345                    Pago Fijo
# 2346                    Pago Fijo
# 2347                    Pago Fijo
# 2348                    Pago Fijo
# 2349                    Pago Fijo
#
# [2350 rows x 23 columns]
